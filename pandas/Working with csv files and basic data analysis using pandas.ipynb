# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1.Reading a CSV

# %% [markdown]
# Reading csv file from local system

# %%
df=pd.read_csv('be.csv')

# %%
df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 22571    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 22572    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 22573    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 22574    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22575    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
df.tail()
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 22571    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 22572    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 22573    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 22574    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22575    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 22571          0  Business Data Collection - BDC
# 22572          0  Business Data Collection - BDC
# 22573          0  Business Data Collection - BDC
# 22574          0  Business Data Collection - BDC
# 22575          0  Business Data Collection - BDC
#
#                                               Group  \
# 22571  Territorial authority by employment variable
# 22572  Territorial authority by employment variable
# 22573  Territorial authority by employment variable
# ...

# %% [markdown]
# Read csv file from github repo

# %%
link='https://github.com/AnumoyMurmu/uni.connect.bootstrap/blob/main/be.csv'
df = pd.read_csv(link)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 link='https://github.com/AnumoyMurmu/uni.connect.bootstrap/blob/main/be.csv'
# ----> 2 df = pd.read_csv(link)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# ### 2. Pandas Info Function

# %%
df.info()

# %% [markdown]
# ### 3. isnull funcyion to check null values

# %%
df.isnull()

# %%
df.head().isnull()

# %%
df.isnull().sum()

# %% [markdown]
# ### 4. Quantile function to get the specific percentile value

# %%
df.describe()

# %%
df['Data_value'].quantile(.1)

# %% [markdown]
# ### 5. Copy function

# %%
de = df.copy()

# %%
de.head(3)

# %%
de['Period']+100

# %%
de['Year+100']=de['Period']+100

# %%
de

# %% [markdown]
# ### 6. Value count functions

# %%
df['Series_reference'].value_counts()

# %% [markdown]
# ### 7.Unique and nunique fucntion

# %%
df['Series_reference'].unique()

# %%
df['Series_reference'].nunique()

# %% [markdown]
# ### 8. dropna() function

# %%
df=pd.read_csv('pl.csv')
df
# Out:
#           Week  Python  Java   C++
# 0    4/21/2019      55  55.0  18.0
# 1    4/28/2019      52  50.0  16.0
# 2     5/5/2019      56  56.0  17.0
# 3    5/12/2019      56  61.0  18.0
# 4    5/19/2019      57  56.0  17.0
# ..         ...     ...   ...   ...
# 257  3/24/2024      79  47.0  19.0
# 258  3/31/2024      81  51.0  19.0
# 259   4/7/2024      77  45.0  18.0
# 260  4/14/2024      78  48.0  19.0
# 261  4/21/2024      71  42.0  17.0
#
# [262 rows x 4 columns]

# %%
df.isnull().sum()

# %%
df.dropna(inplace=True, axis=0)

# %%
df.dropna(inplace=True, axis=1)

# %% [markdown]
# ### 9.Fillna Function

# %%
mis=round(df['Java'].mean(),2)
df['Java'].fillna(mis)

# %%
df['Java'].head(17)

# %% [markdown]
# ### 10. Sample Function

# %%
df

# %%
df.sample()   ##generates random sample everytime

# %% [markdown]
# ### 11. to_csv() function:

# %%
data = {
    'one': pd.Series([1, 2, 3, 4]),    # Series for 'one' column
    'two': pd.Series([5, 6, 7, 8]),    # Series for 'two' column
    'three': pd.Series([9, 10, 11]),   # Series for 'three' column (with fewer values)
    'four': pd.Series([12, 13, 14, 15]),# Series for 'four' column
    'five': pd.Series([16, 17, 18, 19]) # Series for 'five' column
}

df=pd.DataFrame(data)

# %%
df.to_csv('Number.csv')   ##converts to csv file

# %%
df

# %%
df.to_csv('Numbers.csv', index=False)

# %%
df

# %%
data = {
    'one': pd.Series([1, 2, 3, 4]),    # Series for 'one' column
    'two': pd.Series([5, 6, 7, 8]),    # Series for 'two' column
    'three': pd.Series([9, 10, 11]),   # Series for 'three' column (with fewer values)
    'four': pd.Series([12, 13, 14, 15]),# Series for 'four' column
    'five': pd.Series([16, 17, 18, 19]) # Series for 'five' column
}

df=pd.DataFrame(data)

df.to_csv('Num.csv', index=True)

# %% [markdown]
# # A Detailed pandas Profile Report

# %%
# !pip install pandas-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
df=pd.read_csv('pl.csv')
df
# Out:
#           Week  Python  Java   C++
# 0    4/21/2019      55  55.0  18.0
# 1    4/28/2019      52  50.0  16.0
# 2     5/5/2019      56  56.0  17.0
# 3    5/12/2019      56  61.0  18.0
# 4    5/19/2019      57  56.0  17.0
# ..         ...     ...   ...   ...
# 257  3/24/2024      79  47.0  19.0
# 258  3/31/2024      81  51.0  19.0
# 259   4/7/2024      77  45.0  18.0
# 260  4/14/2024      78  48.0  19.0
# 261  4/21/2024      71  42.0  17.0
#
# [262 rows x 4 columns]

# %%
from pandas_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof=ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
# ...

# %%
pip install --upgrade pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof=ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
# ...

# %%
pip install --upgrade bottleneck
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof=ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
# ...
