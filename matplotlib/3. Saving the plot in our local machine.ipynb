# %%
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
plt.figure(figsize=(18,5))   ##width, height
plt.style.use('seaborn-dark')



x=np.linspace(0, 4*np.pi, 100)

#defining the wave
sin_y=np.sin(x)
cos_y=np.cos(x)

plt.plot(x, sin_y, label='sine')
plt.plot(x, cos_y, label='cosine')

plt.legend(loc='upper right')
plt.title('sine-cos wave')

fig=plt.figure()

fig.savefig('sine and cosine.png')
# Out:
# C:\Users\majhi\AppData\Local\Temp\ipykernel_15480\152159618.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-dark')

# %% [markdown]
# ###### 3.1 To display the saved image:

# %%
from IPython.display import Image
Image('sine and cosine.png')
