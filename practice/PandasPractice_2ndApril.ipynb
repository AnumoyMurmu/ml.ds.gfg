# %%
pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
lst=[1,2,3,4]
pd.Series(lst)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
arr=np.array(lst)
pd.Series(arr)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
pd.Series(data=['a','b','c'], index=[1,2,3])
# Out:
# 1    a
# 2    b
# 3    c
# dtype: object

# %%
steps={'day01': 7000,'day02':2772,'day03':987654}
pd.Series(steps)
# Out:
# day01      7000
# day02      2772
# day03    987654
# dtype: int64

# %%
pd.Series(data=[1,2]).repeat(5).reset_index(drop=True)
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# 5    2
# 6    2
# 7    2
# 8    2
# 9    2
# dtype: int64

# %%
pd.Series(data=[12,23]).repeat([12,10]).reset_index(drop=True)
# Out:
# 0     12
# 1     12
# 2     12
# 3     12
# 4     12
# 5     12
# 6     12
# 7     12
# 8     12
# 9     12
# 10    12
# 11    12
# 12    23
# 13    23
# 14    23
# 15    23
# 16    23
# 17    23
# 18    23
# 19    23
# 20    23
# 21    23
# dtype: int64

# %%
s= pd.Series(data=[12,13]).repeat([2,3]).reset_index(drop=True)

# %%
s
# Out:
# 0    12
# 1    12
# 2    13
# 3    13
# 4    13
# dtype: int64

# %%
s[3]
# Out:
# 13

# %%
sr=pd.Series([11,22,3,4224,1])
sr.agg([min,max,sum])
# Out:
# min       1
# max    4224
# sum    4261
# dtype: int64

# %%
sr=pd.Series([11,-22,-3,-4224,1])
sr.abs()
# Out:
# 0      11
# 1      22
# 2       3
# 3    4224
# 4       1
# dtype: int64

# %%
sr1=pd.Series([12,1,2])
sr2=pd.Series([1,123,22])

sr3=sr2.append(sr1)
# Out:
# <ipython-input-11-d3ef515909c6>:4: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sr3=sr2.append(sr1)

# %%
sr3
# Out:
# 0      1
# 1    123
# 2     22
# 0     12
# 1      1
# 2      2
# dtype: int64

# %%
ser=pd.Series(["Eshan Das","data science", "geeks for geeks","Hello world","Machine Learning"])
print(ser.str.upper())
print("-"*40)
print(ser.str.lower())
# Out:
# 0           ESHAN DAS
# 1        DATA SCIENCE
# 2     GEEKS FOR GEEKS
# 3         HELLO WORLD
# 4    MACHINE LEARNING
# dtype: object
# ----------------------------------------
# 0           eshan das
# 1        data science
# 2     geeks for geeks
# 3         hello world
# 4    machine learning
# dtype: object

# %%
for i in ser:
  print(len(i))
# Out:
# 9
# 12
# 15
# 11
# 16

# %%
ser.str.split()
# Out:
# 0           [Eshan, Das]
# 1        [data, science]
# 2    [geeks, for, geeks]
# 3         [Hello, world]
# 4    [Machine, Learning]
# dtype: object

# %%
date=pd.Series(["12/2/1912","3/2/2034","4/2/2056"])

# %%
date.str.split("/")
# Out:
# 0    [12, 2, 1912]
# 1     [3, 2, 2034]
# 2     [4, 2, 2056]
# dtype: object

# %%
date.str.contains("9")
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
date.str.count("2")
# Out:
# 0    3
# 1    2
# 2    2
# dtype: int64

# %%
# DataFrame

pd.DataFrame(date)
# Out:
#            0
# 0  12/2/1912
# 1   3/2/2034
# 2   4/2/2056

# %%
type(pd.DataFrame(date))
# Out:
# pandas.core.frame.DataFrame

# %%
lst=[["anu",23,909],["kanu",33,345],["honu",12,789]]
pd.DataFrame(lst)
# Out:
#       0   1    2
# 0   anu  23  909
# 1  kanu  33  345
# 2  honu  12  789
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8[1].plot(kind='hist', bins=20, title=1)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9[2].plot(kind='hist', bins=20, title=2)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_10.groupby(0).size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
data={"name":["akash","bikash","bhokash"],
      "age":[22,23,45],
      "school":["harvard","Jadavpur","UIt"]}

pd.DataFrame(data)
# Out:
#       name  age    school
# 0    akash   22   harvard
# 1   bikash   23  Jadavpur
# 2  bhokash   45       UIt
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_17.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_18.groupby('school').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
data={'one':pd.Series([12,22,13]),
      'two':pd.Series([34,567,56]),
      'three':pd.Series([66,39,90])}

pf=pd.DataFrame(data)

# %%
pf.loc[0:2]
# Out:
#    one  two  three
# 0   12   34     66
# 1   22  567     39
# 2   13   56     90

# %%
pf.loc[0:1,'one':'two']
# Out:
#    one  two
# 0   12   34
# 1   22  567

# %%
pd.iloc[1:-1,1:-1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-67b2dc5f701a> in <cell line: 1>()
# ----> 1 pd.iloc[1:-1,1:-1]
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'iloc'
